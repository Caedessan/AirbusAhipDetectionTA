# %%
import glob
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.image import imread
import seaborn as sns
import pandas as pd
import ShipDetection
from PIL import Image

# %%
XtrainDir = "data/train_v2"
XtestDir = "data/test_v2"

# %% [markdown]
# Checking train data image size

# %%
dim1 = []
dim2 = []
for imageFilename in glob.glob(XtrainDir+"/*.jpg"):
    img = imread(imageFilename)
    d1,d2,colors = img.shape
    dim1.append(d1)
    dim2.append(d2)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [13], in <cell line: 3>()
#       2 dim2 = []
#       3 for imageFilename in glob.glob(XtrainDir+"/*.jpg"):
# ----> 4     img = imread(imageFilename)
#       5     d1,d2,colors = img.shape
#       6     dim1.append(d1)
#
# File D:\AdankoProject\python\lib\site-packages\matplotlib\image.py:1563, in imread(fname, format)
#    1559             return imread(response, format=ext)
#    1560 with img_open(fname) as image:
#    1561     return (_pil_png_to_float_array(image)
#    1562             if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
# -> 1563             pil_to_array(image))
#
# File D:\AdankoProject\python\lib\site-packages\matplotlib\image.py:1696, in pil_to_array(pilImage)
#    1679 """
#    1680 Load a `PIL image`_ and return it as a numpy int array.
#    1681
#    (...)
#    1692     - (M, N, 4) for RGBA images.
#    1693 """
#    1694 if pilImage.mode in ['RGBA', 'RGBX', 'RGB', 'L']:
#    1695     # return MxNx4 RGBA, MxNx3 RBA, or MxN luminance array
# -> 1696     return np.asarray(pilImage)
#    1697 elif pilImage.mode.startswith('I;16'):
#    1698     # return MxN luminance array of uint16
#    1699     raw = pilImage.tobytes('raw', pilImage.mode)
#
# File D:\AdankoProject\python\lib\site-packages\PIL\Image.py:687, in Image.__array_interface__(self)
#     685     new["data"] = self.tobytes("raw", "L")
#     686 else:
# --> 687     new["data"] = self.tobytes()
#     688 return new
#
# File D:\AdankoProject\python\lib\site-packages\PIL\Image.py:729, in Image.tobytes(self, encoder_name, *args)
#     726 if encoder_name == "raw" and args == ():
#     727     args = self.mode
# --> 729 self.load()
#     731 if self.width == 0 or self.height == 0:
#     732     return b""
#
# File D:\AdankoProject\python\lib\site-packages\PIL\ImageFile.py:251, in ImageFile.load(self)
#     249         break
#     250     else:
# --> 251         raise OSError(
#     252             "image file is truncated "
#     253             f"({len(b)} bytes not processed)"
#     254         )
#     256 b = b + s
#     257 n, err_code = decoder.decode(b)
#
# OSError: image file is truncated (51 bytes not processed)

# %%
sns.jointplot(dim1,dim2)
# Out:
# D:\AdankoProject\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
np.mean(dim1)
# Out:
# 768.0

# %%
imgWidth = 768
imgHeight = 768

# %% [markdown]
# Checking how train data looks like

# %%
testImage = imread(glob.glob(XtrainDir+"/*.jpg")[200])
testImage
# Out:
# array([[[ 2, 47, 50],
#         [ 1, 46, 49],
#         [ 1, 46, 49],
#         ...,
#         [ 0, 36, 44],
#         [ 0, 36, 44],
#         [ 0, 36, 44]],
#
#        [[ 2, 47, 50],
#         [ 1, 46, 49],
#         [ 1, 46, 49],
#         ...,
#         [ 1, 38, 46],
#         [ 1, 38, 46],
#         [ 1, 38, 46]],
#
#        [[ 2, 47, 50],
#         [ 2, 47, 50],
#         [ 1, 46, 49],
#         ...,
#         [ 0, 36, 44],
#         [ 0, 36, 44],
#         [ 0, 36, 44]],
#
#        ...,
#
#        [[80, 98, 76],
#         [53, 70, 51],
#         [43, 60, 42],
#         ...,
#         [ 3, 50, 56],
#         [ 2, 49, 55],
#         [ 2, 49, 55]],
#
#        [[39, 58, 38],
#         [46, 68, 47],
#         [55, 76, 59],
#         ...,
#         [ 2, 49, 55],
#         [ 3, 50, 56],
#         [ 4, 51, 57]],
#
#        [[57, 79, 58],
#         [46, 67, 48],
#         [46, 69, 51],
#         ...,
#         [ 0, 47, 53],
#         [ 2, 49, 55],
#         [ 3, 50, 56]]], dtype=uint8)

# %%
#img = imread(XtestDir+"/"+os.listdir(XtestDir)[8])
img = imread(XtrainDir+ "/000194a2d.jpg")
plt.figure(figsize=(6,6))
plt.imshow(img)

# %% [markdown]
# Checking how mask data looks like

# %%
maskDf = pd.read_csv("train_ship_segmentations_v2.csv")
maskDf.set_index("ImageId", inplace=True)
maskDf
# Out:
#                                                    EncodedPixels
# ImageId
# 00003e153.jpg                                                NaN
# 0001124c7.jpg                                                NaN
# 000155de5.jpg  264661 17 265429 33 266197 33 266965 33 267733...
# 000194a2d.jpg  360486 1 361252 4 362019 5 362785 8 363552 10 ...
# 000194a2d.jpg  51834 9 52602 9 53370 9 54138 9 54906 9 55674 ...
# ...                                                          ...
# fffedbb6b.jpg                                                NaN
# ffff2aa57.jpg                                                NaN
# ffff6e525.jpg                                                NaN
# ffffc50b4.jpg                                                NaN
# ffffe97f3.jpg                                                NaN
#
# [231723 rows x 1 columns]

# %%
im = maskDf.loc["000194a2d.jpg"]
im
# Out:
#                                                    EncodedPixels
# ImageId
# 000194a2d.jpg  360486 1 361252 4 362019 5 362785 8 363552 10 ...
# 000194a2d.jpg  51834 9 52602 9 53370 9 54138 9 54906 9 55674 ...
# 000194a2d.jpg  198320 10 199088 10 199856 10 200624 10 201392...
# 000194a2d.jpg  55683 1 56451 1 57219 1 57987 1 58755 1 59523 ...
# 000194a2d.jpg  254389 9 255157 17 255925 17 256693 17 257461 ...

# %% [markdown]
# Deleting overwhelming amount of pictures without ships

# %%
withoutShipsDf = maskDf[maskDf["EncodedPixels"].isna()==True]

# %%
amountToDelete = len(maskDf)-2*maskDf["EncodedPixels"].count()

# %%
filesToDelete = withoutShipsDf[:amountToDelete]

# %%
for i in filesToDelete.index:
    os.remove(XtrainDir+"/"+i)

# %%
for i in filesToDelete.index:
    try:
        maskDf.drop(index=i, inplace=True)
    except:
        continue

# %%
maskDf.to_csv("train_ship_segmentations_v2.csv",mode='w+')

# %% [markdown]
# Resizing train pictures from 768, 768 to 256, 256

# %%
for path in glob.glob(XtrainDir+"/*.jpg"):
    foo = Image.open(path)
    foo = foo.resize((256,256),Image.ANTIALIAS)
    foo.save(path,quality=95)
# Out:
# C:\Users\adanko\AppData\Local\Temp\ipykernel_9012\3553972626.py:3: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   foo = foo.resize((256,256),Image.ANTIALIAS)

# %% [markdown]
# Decoding/observing pictures with masks

# %%
importlib.reload(ShipDetection)
decodedImage1 = ShipDetection.decode(maskDf.loc["000194a2d.jpg"],imgHeight,imgWidth)

# %%
plt.imshow(decodedImage1)

# %%
imgCopy = img.copy()
for i in range(imgHeight):
    for j in range(imgWidth):
        if decodedImage1[i][j] == 1:
            imgCopy[i][j][0] = 255

# %%
plt.imshow(imgCopy)
